# %%
from sklearn.datasets import load_iris
from dimension import PCA, PCA_varianza
iris = load_iris()
X = iris.data
y = iris.target
pca = PCA(X,2)
print(pca)
# Out:
# [[-2.26470281 -0.4800266 ]
#  [-2.08096115  0.67413356]
#  [-2.36422905  0.34190802]
#  [-2.29938422  0.59739451]
#  [-2.38984217 -0.64683538]
#  [-2.07563095 -1.48917752]
#  [-2.44402884 -0.0476442 ]
#  [-2.23284716 -0.22314807]
#  [-2.33464048  1.11532768]
#  [-2.18432817  0.46901356]
#  [-2.1663101  -1.04369065]
#  [-2.32613087 -0.13307834]
#  [-2.2184509   0.72867617]
#  [-2.6331007   0.96150673]
#  [-2.1987406  -1.86005711]
#  [-2.26221453 -2.68628449]
#  [-2.2075877  -1.48360936]
#  [-2.19034951 -0.48883832]
#  [-1.898572   -1.40501879]
#  [-2.34336905 -1.12784938]
#  [-1.914323   -0.40885571]
#  [-2.20701284 -0.92412143]
#  [-2.7743447  -0.45834367]
#  [-1.81866953 -0.08555853]
#  [-2.22716331 -0.13725446]
#  [-1.95184633  0.62561859]
#  [-2.05115137 -0.24216355]
#  [-2.16857717 -0.52714953]
#  [-2.13956345 -0.31321781]
#  [-2.26526149  0.3377319 ]
#  [-2.14012214  0.50454069]
#  [-1.83159477 -0.42369507]
#  [-2.61494794 -1.79357586]
#  [-2.44617739 -2.15072788]
# ...

# %%
PCA_varianza(X)
# Out:
# Componente Principal 1: 0.7296
# Componente Principal 2: 0.9581
# Componente Principal 3: 0.9948
# Componente Principal 4: 1.0000

# %%
from datos import divide

X_train, X_test, y_train, y_test = divide(X, y, test_size=0.4, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((90, 4), (60, 4), (90,), (60,))

# %%
import pandas as pd
vinos = pd.read_csv('dataset/wine.csv')
a = vinos.iloc[:, 1:].values
b = vinos.iloc[:, 0].values
X_train, X_test, y_train, y_test = divide(a, b, test_size=0.2, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((143, 13), (35, 13), (143,), (35,))

# %%
pca_vinos = PCA(a,7)
print(pca_vinos)
# Out:
# [[-3.31675081  1.44346263 -0.16573904 ...  0.69304284  0.22388013
#   -0.59642655]
#  [-2.20946492 -0.33339289 -2.02645737 ... -0.25765463  0.92712024
#   -0.05377561]
#  [-2.51674015  1.0311513   0.98281867 ... -0.25103312 -0.54927605
#   -0.42420545]
#  ...
#  [ 2.67783946  2.76089913 -0.94094188 ...  1.271355   -0.27306792
#   -0.67923541]
#  [ 2.38701709  2.29734668 -0.5506962  ...  0.81395522 -1.17878298
#   -0.63397527]
#  [ 3.20875816  2.76891957  1.01391366 ... -0.89519259 -0.29609218
#   -0.00574126]]

# %%
PCA_varianza(a)
# Out:
# Componente Principal 1: 0.3620
# Componente Principal 2: 0.5541
# Componente Principal 3: 0.6653
# Componente Principal 4: 0.7360
# Componente Principal 5: 0.8016
# Componente Principal 6: 0.8510
# Componente Principal 7: 0.8934
# Componente Principal 8: 0.9202
# Componente Principal 9: 0.9424
# Componente Principal 10: 0.9617
# Componente Principal 11: 0.9791
# Componente Principal 12: 0.9920
# Componente Principal 13: 1.0000
